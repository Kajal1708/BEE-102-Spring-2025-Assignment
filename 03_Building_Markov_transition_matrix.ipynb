# %%
#markov transition matrix
import numpy as np
import pandas as pd

# Define the DNA alphabet
nucleotides = ['A', 'C', 'G', 'T']

# Initialize count matrix
transition_counts = pd.DataFrame(
    data=0, index=nucleotides, columns=nucleotides, dtype=int
)

# Example input sequence (replace this with your actual input)
sequence = "ACGTACGTGCGTACGTAGCTAGCAGT"

# Clean the sequence: uppercase and keep only valid nucleotides
sequence = ''.join([base for base in sequence.upper() if base in nucleotides])

# Count transitions
for i in range(len(sequence) - 1):
    curr = sequence[i]
    next_ = sequence[i + 1]
    transition_counts.loc[curr, next_] += 1

# Convert counts to probabilities (normalize rows)
transition_matrix = transition_counts.div(transition_counts.sum(axis=1), axis=0)

# Print transition matrix
print("Markov Transition Matrix (Probabilities):\n")
print(transition_matrix)
# Out:
# Markov Transition Matrix (Probabilities):
#
#           A      C         G         T
# A  0.000000  0.500  0.500000  0.000000
# C  0.166667  0.000  0.666667  0.166667
# G  0.000000  0.375  0.000000  0.625000
# T  0.800000  0.000  0.200000  0.000000
